# %%
# !pip3 install pandas --user
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import os
import sys

# %%
path = './Revision_Depth1.pickle'
df_1 = pd.read_pickle(path)
df_1
# Out:
#                                               Article_Name     Revision_Tag  \
# 2385710                             Prepare_for_an_MRI.txt  Begin_Revisions
# 349075                         Add_Nitrogen_to_Compost.txt  Begin_Revisions
# 3214356                            Write_a_Korean_Song.txt  Begin_Revisions
# 779958                                  Date_a_Vampire.txt  Begin_Revisions
# 350938                Ask_For_an_Increase_in_Allowance.txt  Begin_Revisions
# ...                                                    ...              ...
# 3197610                    Write_a_Literary_Commentary.txt  Begin_Revisions
# 1158867                       Encourage_a_Child_to_Eat.txt  Begin_Revisions
# 1575470  Handle_People_Who_Do_Not_Understand_Your_Anxio...  Begin_Revisions
# 2801521                                Reset_Your_BIOS.txt  Begin_Revisions
# 2391334                    Prevent_a_Cat_from_Spraying.txt  Begin_Revisions
#
#          Revision_Length  BLEU_Score  \
# ...

# %%
path = './Revision_Depth_Multiple.pkl'
df_mul = pd.read_pickle(path)
df_mul
# Out:
#                                          Article_Name      Revision_Tag  \
# 301972  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# 301973  Be_Positive_when_Surrounded_by_Negativity.txt  Inside_Revisions
# 301977  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# 301978  Be_Positive_when_Surrounded_by_Negativity.txt  Inside_Revisions
# 301979  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# ...                                               ...               ...
# 307355                  Be_a_Kid_Environmentalist.txt  Inside_Revisions
# 307356                  Be_a_Kid_Environmentalist.txt  Inside_Revisions
# 307357                  Be_a_Kid_Environmentalist.txt  Inside_Revisions
# 307358                  Be_a_Kid_Environmentalist.txt  Inside_Revisions
# 307359                  Be_a_Kid_Environmentalist.txt  Inside_Revisions
#
#         Revision_Length  BLEU_Score Section_Src  Line_No_Src  \
# ...

# %%
topic = list(df_mul['Article_Name'])[0]
df_mul.loc[df_mul['Article_Name'] == topic]
# Out:
#                                          Article_Name      Revision_Tag  \
# 301972  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# 301973  Be_Positive_when_Surrounded_by_Negativity.txt  Inside_Revisions
# 301977  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# 301978  Be_Positive_when_Surrounded_by_Negativity.txt  Inside_Revisions
# 301979  Be_Positive_when_Surrounded_by_Negativity.txt   Begin_Revisions
# 301980  Be_Positive_when_Surrounded_by_Negativity.txt  Inside_Revisions
#
#         Revision_Length  BLEU_Score Section_Src  Line_No_Src  \
# 301972                2       0.659       Intro           92
# 301973                2       0.323    ## Steps          257
# 301977                2       0.761    ## Steps          231
# 301978                2       0.507    ## Steps          256
# 301979                2       0.752    ## Steps          231
# 301980                2       0.472    ## Steps          256
#
# ...
